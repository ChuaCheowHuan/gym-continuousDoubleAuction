# %%
import os
print(os.getcwd())
# Out:
# /workspace/code/gym-continuousDoubleAuction/gym_continuousDoubleAuction

# %%
# %run ../gym_continuousDoubleAuction/visualize_orderbook.py
# Out:
# Loading data from latest_episode_data.json...
# Found 1025 steps in episode.
# Plot saved to orderbook_visualization.png

# %%
# %run ../gym_continuousDoubleAuction/visualize_nav.py
# Out:
# Loading data from latest_episode_data.json...
# Processing 1025 steps...
# Visualization saved to nav_visualization.png

# %%
# %run ../gym_continuousDoubleAuction/visualize_rewards.py
# Out:
# Loading data from latest_episode_data.json...
# Processing 1025 steps...
# Visualization saved to cumulative_rewards_visualization.png

# %%
from datetime import datetime

now = datetime.now()
formatted = now.strftime("%Y-%m-%d %H:%M:%S")
print(formatted)  # e.g., "2025-12-22 10:30:45"
# Out:
# 2026-01-05 14:46:34
