# %% [markdown]
# # Test tf GPU with rllib

# %%
# !whoami
# Out:
# root

# %%
# !cat /etc/os-release
# Out:
# PRETTY_NAME="Ubuntu 22.04.3 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.3 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy

# %%
# !python3 --version
# Out:
# Python 3.10.12

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.10.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google-pasta, grpcio, h5py, keras, keras-preprocessing, libclang, numpy, opt-einsum, packaging, protobuf, setuptools, six, tensorboard, tensorflow-estimator, tensorflow-io-gcs-filesystem, termcolor, typing-extensions, wrapt
# Required-by:

# %%
# !pip show ray
# Out:
# Name: ray
# Version: 2.35.0
# Summary: Ray provides a simple, universal API for building distributed applications.
# Home-page: https://github.com/ray-project/ray
# Author: Ray Team
# Author-email: ray-dev@googlegroups.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: aiosignal, click, filelock, frozenlist, jsonschema, msgpack, packaging, protobuf, pyyaml, requests
# Required-by:

# %%
# !pip show gymnasium
# Out:
# Name: gymnasium
# Version: 0.28.1
# Summary: A standard API for reinforcement learning and a diverse set of reference environments (formerly Gym).
# Home-page: https://farama.org
# Author:
# Author-email: Farama Foundation <contact@farama.org>
# License: MIT License
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: cloudpickle, farama-notifications, jax-jumpy, numpy, typing-extensions
# Required-by:

# %%
import tensorflow as tf
print("CUDA version:", tf.sysconfig.get_build_info()["cuda_version"])
print("cuDNN version:", tf.sysconfig.get_build_info()["cudnn_version"])
# Out:
# 2025-07-03 12:58:00.147983: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-03 12:58:00.216630: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-03 12:58:00.237412: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-03 12:58:00.631193: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-07-03 12:58:00.631304: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-07-03 12:58:00.631311: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# CUDA version: 11.2
# cuDNN version: 8

# %%
print('Num GPUs Available: ', len(tf.config.list_physical_devices('GPU')))
print(tf.test.is_built_with_cuda())
print(tf.test.gpu_device_name())
# Out:
# Num GPUs Available:  1
# True
# /device:GPU:0
# 2025-07-03 13:02:23.276312: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-03 13:02:23.276396: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-03 13:02:23.276432: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-03 13:02:23.276600: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-03 13:02:23.276610: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1700] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-07-03 13:02:23.276644: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-07-03 13:02:23.276663: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
# !nvidia-smi
# Out:
# Thu Jul  3 12:58:01 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.02              Driver Version: 560.94         CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060        On  |   00000000:01:00.0  On |                  N/A |
# |  0%   45C    P8             N/A /  115W |     745MiB /   8188MiB |      1%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A        31      G   /Xwayland                                   N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
# !ldconfig -p | grep nvidia
# Out:
# 	libnvidia-ml.so.1 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libnvidia-ml.so.1

# %%
# !ldconfig -p | grep cuda
# Out:
# 	libnvrtc.so.11.2 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libnvrtc.so.11.2
# 	libnvrtc-builtins.so.11.8 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libnvrtc-builtins.so.11.8
# 	libnvjpeg.so.11 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libnvjpeg.so.11
# 	libnvblas.so.11 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libnvblas.so.11
# 	libnvToolsExt.so.1 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libnvToolsExt.so.1
# 	libnvToolsExt.so (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libnvToolsExt.so
# 	libnpps.so.11 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libnpps.so.11
# 	libnppitc.so.11 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libnppitc.so.11
# 	libnppisu.so.11 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libnppisu.so.11
# 	libnppist.so.11 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libnppist.so.11
# 	libnppim.so.11 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libnppim.so.11
# 	libnppig.so.11 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libnppig.so.11
# 	libnppif.so.11 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libnppif.so.11
# 	libnppidei.so.11 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libnppidei.so.11
# 	libnppicc.so.11 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libnppicc.so.11
# 	libnppial.so.11 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libnppial.so.11
# 	libnppc.so.11 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libnppc.so.11
# 	libicudata.so.70 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libicudata.so.70
# 	libcusparse.so.11 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libcusparse.so.11
# 	libcusolverMg.so.11 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libcusolverMg.so.11
# 	libcusolver.so.11 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libcusolver.so.11
# 	libcurand.so.10 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libcurand.so.10
# 	libcufile_rdma.so.1 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libcufile_rdma.so.1
# 	libcufile.so.0 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libcufile.so.0
# 	libcufftw.so.10 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libcufftw.so.10
# 	libcufft.so.10 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libcufft.so.10
# 	libcudart.so.11.0 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libcudart.so.11.0
# 	libcudadebugger.so.1 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcudadebugger.so.1
# 	libcuda.so.1 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcuda.so.1
# 	libcuda.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcuda.so
# 	libcublasLt.so.11 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libcublasLt.so.11
# 	libcublas.so.11 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libcublas.so.11
# 	libOpenCL.so.1 (libc6,x86-64) => /usr/local/cuda/targets/x86_64-linux/lib/libOpenCL.so.1

# %%
# !ldconfig -p | grep cudnn
# Out:
# 	libcudnn_ops_train.so.8 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcudnn_ops_train.so.8
# 	libcudnn_ops_infer.so.8 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcudnn_ops_infer.so.8
# 	libcudnn_cnn_train.so.8 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcudnn_cnn_train.so.8
# 	libcudnn_cnn_infer.so.8 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcudnn_cnn_infer.so.8
# 	libcudnn_adv_train.so.8 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcudnn_adv_train.so.8
# 	libcudnn_adv_infer.so.8 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcudnn_adv_infer.so.8
# 	libcudnn.so.8 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcudnn.so.8

# %%
import ray
from ray.rllib.algorithms.ppo import PPOConfig

ray.shutdown()
ray.init()

config = (
    PPOConfig()
    .environment(env="CartPole-v1")
    .framework("tf2")
    .resources(num_gpus=1)  # GPU for learner instead
    # .learners(num_learners=1, num_gpus_per_learner=1)
    # .api_stack(enable_rl_module_and_learner=False,
    #            enable_env_runner_and_connector_v2=False)
)
algo = config.build()
for _ in range(3):
    result = algo.train()
    # print("iter:", result["iteration"], "reward:", result["episode_reward_mean"])
    print(result)

ray.shutdown()
# Out:
# 2025-07-03 12:58:17,840	WARNING services.py:2017 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67096576 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=4.78gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# 2025-07-03 12:58:17,889	INFO worker.py:1783 -- Started a local Ray instance.
# 2025-07-03 12:58:24,031	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# 2025-07-03 12:58:25,852	WARNING tf_utils.py:797 -- KL divergence is non-finite, this will likely destabilize your model and the training process. Action(s) in a specific state have near-zero probability. This can happen naturally in deterministic environments where the optimal policy has zero mass for a specific action. To fix this issue, consider setting the coefficient for the KL loss term to zero or increasing policy entropy.
# 2025-07-03 12:58:25,965	WARNING tf_utils.py:797 -- KL divergence is non-finite, this will likely destabilize your model and the training process. Action(s) in a specific state have near-zero probability. This can happen naturally in deterministic environments where the optimal policy has zero mass for a specific action. To fix this issue, consider setting the coefficient for the KL loss term to zero or increasing policy entropy.
# 2025-07-03 12:58:26,215	WARNING tf_utils.py:797 -- KL divergence is non-finite, this will likely destabilize your model and the training process. Action(s) in a specific state have near-zero probability. This can happen naturally in deterministic environments where the optimal policy has zero mass for a specific action. To fix this issue, consider setting the coefficient for the KL loss term to zero or increasing policy entropy.
# {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'learner_stats': {'cur_kl_coeff': 0.20000000298023224, 'cur_lr': 4.999999873689376e-05, 'total_loss': 8.832029, 'policy_loss': -0.035757918, 'vf_loss': 8.862249, 'vf_explained_var': 0.01098002, 'kl': 0.027687581, 'entropy': 0.6666337, 'entropy_coeff': 0.0}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 480.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}}, 'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_agent_steps_sampled': 4000, 'num_agent_steps_trained': 4000}, 'env_runners': {'episode_reward_max': 97.0, 'episode_reward_min': 9.0, 'episode_reward_mean': 22.81714285714286, 'episode_len_mean': 22.81714285714286, 'episode_media': {}, 'episodes_timesteps_total': 3993, 'policy_reward_min': {'default_policy': 9.0}, 'policy_reward_max': {'default_policy': 97.0}, 'policy_reward_mean': {'default_policy': 22.81714285714286}, 'custom_metrics': {}, 'hist_stats': {'episode_reward':
, 81, 61, 29, 37, 36, 50, 65, 32, 35, 9, 23, 13, 36, 86, 30, 28, 11, 55, 18, 39, 31, 15, 51, 50, 29, 35, 12, 22, 29, 34, 71, 32, 19, 33, 46, 41, 30, 56, 25, 35, 21], 'policy_default_policy_reward': [12.0, 30.0, 60.0, 15.0, 16.0, 12.0, 47.0, 13.0, 42.0, 102.0, 39.0, 73.0, 76.0, 32.0, 55.0, 51.0, 18.0, 100.0, 28.0, 84.0, 43.0, 40.0, 38.0, 76.0, 87.0, 21.0, 28.0, 16.0, 33.0, 50.0, 50.0, 19.0, 28.0, 46.0, 23.0, 67.0, 66.0, 78.0, 60.0, 26.0, 52.0, 18.0, 77.0, 43.0, 32.0, 32.0, 93.0, 93.0, 19.0, 31.0, 39.0, 39.0, 33.0, 151.0, 30.0, 25.0, 60.0, 18.0, 45.0, 81.0, 61.0, 29.0, 37.0, 36.0, 50.0, 65.0, 32.0, 35.0, 9.0, 23.0, 13.0, 36.0, 86.0, 30.0, 28.0, 11.0, 55.0, 18.0, 39.0, 31.0, 15.0, 51.0, 50.0, 29.0, 35.0, 12.0, 22.0, 29.0, 34.0, 71.0, 32.0, 19.0, 33.0, 46.0, 41.0, 30.0, 56.0, 25.0, 35.0, 21.0]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.1337561194915809, 'mean_inference_ms': 0.6382263721368081, 'mean_action_processing_ms': 0.04901261658023444, 'mean_env_wait_ms': 0.025271513155141916, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'connector_metrics': {'ObsPreprocessorConnector_ms': 0.0022492408752441406, 'StateBufferConnector_ms': 0.0019054412841796875, 'ViewRequirementAgentConnector_ms': 0.046478986740112305}, 'num_episodes': 91, 'episode_return_max': 151.0, 'episode_return_min': 9.0, 'episode_return_mean': 42.21, 'episodes_this_iter': 91}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 8000, 'num_agent_steps_trained': 8000, 'num_env_steps_sampled': 8000, 'num_env_steps_trained': 8000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 332.196306104629, 'num_env_steps_trained_throughput_per_sec': 332.196306104629, 'timesteps_total': 8000, 'num_env_steps_sampled_lifetime': 8000, 'num_agent_steps_sampled_lifetime': 8000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 8000, 'timers': {'training_iteration_time_ms': 11490.747, 'restore_workers_time_ms': 0.01, 'training_step_time_ms': 11490.707, 'sample_time_ms': 1727.048, 'learn_time ...
# {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'learner_stats': {'cur_kl_coeff': 0.30000001192092896, 'cur_lr': 4.999999873689376e-05, 'total_loss': 9.414658, 'policy_loss': -0.017090226, 'vf_loss': 9.429151, 'vf_explained_var': 0.05130594, 'kl': 0.008658304, 'entropy': 0.5808599, 'entropy_coeff': 0.0}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 2400.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}}, 'num_env_steps_sampled': 12000, 'num_env_steps_trained': 12000, 'num_agent_steps_sampled': 12000, 'num_agent_steps_trained': 12000}, 'env_runners': {'episode_reward_max': 305.0, 'episode_reward_min': 9.0, 'episode_reward_mean': 66.1, 'episode_len_mean': 66.1, 'episode_media': {}, 'episodes_timesteps_total': 6610, 'policy_reward_min': {'default_policy': 9.0}, 'policy_reward_max': {'default_policy': 305.0}, 'policy_reward_mean': {'default_policy': 66.1}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [46.0, 23.0, 67.0, 66.0, 78.0, 60.0, 26.0, 52.0, 18.0, 77.0, 43.0, 32.0, 32.0, 93.0, 93.0, 19.0, 31.0, 39.0, 39.0, 33.0, 151.0, 30.0, 25.0, 60.0, 18.0, 45.0, 81.0, 61.0, 29.0, 37.0, 36.0, 50.0, 65.0, 32.0, 35.0, 9.0, 23.0, 13.0, 36.0, 86.0, 30.0, 28.0, 11.0, 55.0, 18.0, 39.0, 31.0, 15.0, 51.0, 50.0, 29.0, 35.0, 12.0, 22.0, 29.0, 34.0, 71.0, 32.0, 19.0, 33.0, 46.0, 41.0, 30.0, 56.0, 25.0, 35.0, 21.0, 189.0, 60.0, 79.0, 128.0, 35.0, 122.0, 246.0, 99.0, 81.0, 20.0, 43.0, 179.0, 133.0, 86.0, 52.0, 52.0, 106.0, 268.0, 73.0, 148.0, 102.0, 96.0, 184.0, 70.0, 40.0, 184.0, 86.0, 61.0, 99.0, 206.0, 305.0, 82.0, 109.0], 'episode_lengths': [46, 23, 67, 66, 78, 60, 26, 52, 18, 77, 43, 32, 32, 93, 93, 19, 31, 39, 39, 33, 151, 30, 25, 60, 18, 45, 81, 61, 29, 37, 36, 50, 65, 32, 35, 9, 23, 13, 36, 86, 30, 28, 11, 55, 18, 39, 31, 15, 51, 50, 29, 35, 12, 22, 29, 34, 71, 32, 19, 33, 46, 41, 30, 56, 25, 35, 21, 189, 60, 79, 128, 35, 122, 246, 99, 81, 20, 43, 179, 133, 86, 52, 52, 106, 268, 73, 148, 102, 96, 184, 70, 40, 184, 86, 61, 99, 206, 305, 82, 109], 'policy_default_policy_reward': [46.0, 23.0, 67.0, 66.0, 78.0, 60.0, 26.0, 52.0, 18.0, 77.0, 43.0, 32.0, 32.0, 93.0, 93.0, 19.0, 31.0, 39.0, 39.0, 33.0, 151.0, 30.0, 25.0, 60.0, 18.0, 45.0, 81.0, 61.0, 29.0, 37.0, 36.0, 50.0, 65.0, 32.0, 35.0, 9.0, 23.0, 13.0, 36.0, 86.0, 30.0, 28.0, 11.0, 55.0, 18.0, 39.0, 31.0, 15.0, 51.0, 50.0, 29.0, 35.0, 12.0, 22.0, 29.0, 34.0, 71.0, 32.0, 19.0, 33.0, 46.0, 41.0, 30.0, 56.0, 25.0, 35.0, 21.0, 189.0, 60.0, 79.0, 128.0, 35.0, 122.0, 246.0, 99.0, 81.0, 20.0, 43.0, 179.0, 133.0, 86.0, 52.0, 52.0, 106.0, 268.0, 73.0, 148.0, 102.0, 96.0, 184.0, 70.0, 40.0, 184.0, 86.0, 61.0, 99.0, 206.0, 305.0, 82.0, 109.0]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.1322115534096105, 'mean_inference_ms': 0.6329189842248288, 'mean_action_processing_ms': 0.04886209185862762, 'mean_env_wait_ms': 0.025203937009263922, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'connector_metrics': {'ObsPreprocessorConnector_ms': 0.002222776412963867, 'StateBufferConnector_ms': 0.001842498779296875, 'ViewRequirementAgentConnector_ms': 0.04647707939147949}, 'num_episodes': 33, 'episode_return_max': 305.0, 'episode_return_min': 9.0, 'episode_return_mean': 66.1, 'episodes_this_iter': 33}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 12000, 'num_agent_steps_trained': 12000, 'num_env_steps_sampled': 12000, 'num_env_steps_trained': 12000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 262.6890839537209, 'num_env_steps_trained_throughput_per_sec': 262.6890839537209, 'timesteps_total': 12000, 'num_env_steps_sampled_lifetime': 12000, 'num_agent_steps_sampled_lifetime': 12000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 12000, 'timers': {'training_iteration_time_ms': 12736.211, 'restore_workers_time_ms': 0.009, 'training_step_time_ms': 127 ...
